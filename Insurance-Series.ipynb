# %% [markdown]
# # Insurance Series

# %% [markdown]
# We will propose a relevant and exhaustive market risk analysis of a Bank. The bank is **JP Morgan**

# %% [markdown]
# ## Import Libraries

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import Series_Functions as sf
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

plt.rcParams['figure.figsize'] = [15, 8]

# %% [markdown]
# ## Download the Data

# %%
ticker = 'CS.PA'
prices = sf.get_data(ticker)

# %% [markdown]
# We compute the returns

# %%
returns = sf.get_returns(prices)

# %% [markdown]
# We plot the returns for the insurance

# %%
sf.plot_returns(returns, ticker)

# %% [markdown]
# Stationarity test :

# %%
sf.Dickey_Fuller(returns, ticker)
# Out:
# Augmented Dickey_fuller Statistic for CS.PA: -11.548990
# p-value: 0.000000
# critical values at different levels:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# ## Estimation of the VaR

# %% [markdown]
# ### Non parametric method

# %%
VaR_NonParam = sf.weighted_hs_var(returns=returns, confidence_level=95, window=100, ticker=ticker)

# %% [markdown]
# ### Parametric method

# %%
p,q = sf.optimize_garch(returns=returns, bounds=[9,9])
VaR_Param = sf.garch_var(returns=returns, confidence_level=95, p=p, q=q, ticker=ticker)

# %% [markdown]
# ## Expected shortfall

# %%
Es = sf.expected_shortfall(returns=returns, confidence_level=95, window=250, ticker=ticker)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-9745a6513ade> in <module>
# ----> 1 Es = sf.expected_shortfall(returns=returns, confidence_level=95, window=250, ticker=ticker)
#
# ~/Desktop/centrale marseille/cours/3A/AMSE/Econometrie/Project-Econometrics/Series_Functions.py in expected_shortfall(returns, confidence_level, window, ticker, disp)
#     370
#     371         # Compute the ES for the current window
# --> 372         es = current_returns[current_returns <= var].mean()
#     373
#     374         # Store the ES in the dataframe
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py in __le__(self, other)
#      52     @unpack_zerodim_and_defer("__le__")
#      53     def __le__(self, other):
# ---> 54         return self._cmp_method(other, operator.le)
#      55
#      56     @unpack_zerodim_and_defer("__gt__")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6235
#    6236         if isinstance(other, Series) and not self._indexed_same(other):
# -> 6237             raise ValueError("Can only compare identically-labeled Series objects")
#    6238
#    6239         lvalues = self._values
#
# ValueError: Can only compare identically-labeled Series objects
